# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df = pd.read_csv('energy_efficiency_data.csv')

# %%
df.head()
# Out:
#    Relative_Compactness  Surface_Area  Wall_Area  Roof_Area  Overall_Height
# 0                  0.98         514.5      294.0     110.25             7.0  \
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    Orientation  Glazing_Area  Glazing_Area_Distribution  Heating_Load
# 0            2           0.0                          0         15.55  \
# 1            3           0.0                          0         15.55
# 2            4           0.0                          0         15.55
# 3            5           0.0                          0         15.55
# 4            2           0.0                          0         20.84
#
#    Cooling_Load
# 0         21.33
# 1         21.33
# 2         21.33
# 3         21.33
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Relative_Compactness       768 non-null    float64
#  1   Surface_Area               768 non-null    float64
#  2   Wall_Area                  768 non-null    float64
#  3   Roof_Area                  768 non-null    float64
#  4   Overall_Height             768 non-null    float64
#  5   Orientation                768 non-null    int64
#  6   Glazing_Area               768 non-null    float64
#  7   Glazing_Area_Distribution  768 non-null    int64
#  8   Heating_Load               768 non-null    float64
#  9   Cooling_Load               768 non-null    float64
# dtypes: float64(8), int64(2)
# memory usage: 60.1 KB

# %%
df.describe()
# Out:
#        Relative_Compactness  Surface_Area   Wall_Area   Roof_Area
# count            768.000000    768.000000  768.000000  768.000000  \
# mean               0.764167    671.708333  318.500000  176.604167
# std                0.105777     88.086116   43.626481   45.165950
# min                0.620000    514.500000  245.000000  110.250000
# 25%                0.682500    606.375000  294.000000  140.875000
# 50%                0.750000    673.750000  318.500000  183.750000
# 75%                0.830000    741.125000  343.000000  220.500000
# max                0.980000    808.500000  416.500000  220.500000
#
#        Overall_Height  Orientation  Glazing_Area  Glazing_Area_Distribution
# count       768.00000   768.000000    768.000000                  768.00000  \
# mean          5.25000     3.500000      0.234375                    2.81250
# std           1.75114     1.118763      0.133221                    1.55096
# ...

# %%
heat = df.copy()

# %%
heat.head()
# Out:
#    Relative_Compactness  Surface_Area  Wall_Area  Roof_Area  Overall_Height
# 0                  0.98         514.5      294.0     110.25             7.0  \
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    Orientation  Glazing_Area  Glazing_Area_Distribution  Heating_Load
# 0            2           0.0                          0         15.55  \
# 1            3           0.0                          0         15.55
# 2            4           0.0                          0         15.55
# 3            5           0.0                          0         15.55
# 4            2           0.0                          0         20.84
#
#    Cooling_Load
# 0         21.33
# 1         21.33
# 2         21.33
# 3         21.33
# ...

# %%
heat = heat.drop('Cooling_Load', axis=1)

# %%
heat.head()
# Out:
#    Relative_Compactness  Surface_Area  Wall_Area  Roof_Area  Overall_Height
# 0                  0.98         514.5      294.0     110.25             7.0  \
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    Orientation  Glazing_Area  Glazing_Area_Distribution  Heating_Load
# 0            2           0.0                          0         15.55
# 1            3           0.0                          0         15.55
# 2            4           0.0                          0         15.55
# 3            5           0.0                          0         15.55
# 4            2           0.0                          0         20.84

# %%
cool = df.copy()

# %%
cool = df.drop('Heating_Load', axis = 1)

# %%
cool.head()
# Out:
#    Relative_Compactness  Surface_Area  Wall_Area  Roof_Area  Overall_Height
# 0                  0.98         514.5      294.0     110.25             7.0  \
# 1                  0.98         514.5      294.0     110.25             7.0
# 2                  0.98         514.5      294.0     110.25             7.0
# 3                  0.98         514.5      294.0     110.25             7.0
# 4                  0.90         563.5      318.5     122.50             7.0
#
#    Orientation  Glazing_Area  Glazing_Area_Distribution  Cooling_Load
# 0            2           0.0                          0         21.33
# 1            3           0.0                          0         21.33
# 2            4           0.0                          0         21.33
# 3            5           0.0                          0         21.33
# 4            2           0.0                          0         28.28

# %%
sns.pairplot(heat, hue='Heating_Load', palette='crest')

# %%
sns.pairplot(cool, hue='Cooling_Load', palette='viridis')

# %%
sns.jointplot(x='Relative_Compactness', y='Surface_Area', data=df, color='green')

# %%
corr = df.corr(numeric_only=True)

# %%
corr
# Out:
#                            Relative_Compactness  Surface_Area     Wall_Area
# Relative_Compactness               1.000000e+00 -9.919015e-01 -2.037817e-01  \
# Surface_Area                      -9.919015e-01  1.000000e+00  1.955016e-01
# Wall_Area                         -2.037817e-01  1.955016e-01  1.000000e+00
# Roof_Area                         -8.688234e-01  8.807195e-01 -2.923165e-01
# Overall_Height                     8.277473e-01 -8.581477e-01  2.809757e-01
# Orientation                        4.678592e-17 -3.459372e-17 -2.429499e-17
# Glazing_Area                      -2.960552e-15  3.636925e-15 -8.567455e-17
# Glazing_Area_Distribution         -7.107006e-16  2.438409e-15  2.067384e-16
# Heating_Load                       6.222722e-01 -6.581202e-01  4.556712e-01
# Cooling_Load                       6.343391e-01 -6.729989e-01  4.271170e-01
#
#                               Roof_Area  Overall_Height   Orientation
# ...

# %%
sns.heatmap(corr, annot=True, fmt = ".1f", linewidths=2, cmap='crest')
# Out:
# <AxesSubplot: >

# %% [markdown]
# # Model for Heating Load

# %% [markdown]
# ### Training the data

# %%
heat.columns
# Out:
# Index(['Relative_Compactness', 'Surface_Area', 'Wall_Area', 'Roof_Area',
#        'Overall_Height', 'Orientation', 'Glazing_Area',
#        'Glazing_Area_Distribution', 'Heating_Load'],
#       dtype='object')

# %%
X = df[['Relative_Compactness', 'Surface_Area', 'Wall_Area', 'Roof_Area',
       'Overall_Height', 'Orientation', 'Glazing_Area',
       'Glazing_Area_Distribution']]
y = df['Heating_Load']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %% [markdown]
# ### Creating and training the model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Evaluation

# %%
print(lm.intercept_)
# Out:
# 84.3896778614357

# %%
coeff = pd.DataFrame(lm.coef_, X.columns, columns=['Coefficients'])

# %%
coeff
# Out:
#                            Coefficients
# Relative_Compactness      -6.518757e+01
# Surface_Area              -1.514436e+12
# Wall_Area                  1.514436e+12
# Roof_Area                  3.028872e+12
# Overall_Height             4.076666e+00
# Orientation               -2.138931e-02
# Glazing_Area               2.002612e+01
# Glazing_Area_Distribution  2.202706e-01

# %% [markdown]
# ### Prediction from the model

# %%
pred = lm.predict(X_test)

# %%
plt.scatter(y_test, pred, )

# %%
sns.histplot((y_test-pred),bins=50, kde=True)
# Out:
# <AxesSubplot: xlabel='Heating_Load', ylabel='Count'>

# %% [markdown]
# ### Regression Evaluation Metrics

# %%
from sklearn import metrics

# %%
print('MAE: ', metrics.mean_absolute_error(y_test, pred))
print('MSE: ', metrics.mean_squared_error(y_test, pred))
print('RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE:  1.9425813590345253
# MSE:  7.533909854534024
# RMSE:  2.7447968694484524

# %% [markdown]
# # Model for Cooling Load

# %% [markdown]
# ### Training the data

# %%
X = cool[['Relative_Compactness', 'Surface_Area', 'Wall_Area', 'Roof_Area',
       'Overall_Height', 'Orientation', 'Glazing_Area',
       'Glazing_Area_Distribution']]
y = cool['Cooling_Load']

# %%
from sklearn.model_selection import train_test_split

# %%
X_tain, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=101)

# %% [markdown]
# ### Creating and Training the model

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ### Model Evaluation

# %%
print(lm.intercept_)
# Out:
# 97.2875909365751

# %%
coeff = pd.DataFrame(lm.coef_, X.columns, columns=['Cofficients'])

# %%
coeff
# Out:
#                             Cofficients
# Relative_Compactness      -6.985046e+01
# Surface_Area              -1.038518e+12
# Wall_Area                  1.038518e+12
# Roof_Area                  2.077037e+12
# Overall_Height             4.049789e+00
# Orientation                1.421723e-01
# Glazing_Area               1.538424e+01
# Glazing_Area_Distribution  3.679173e-02

# %% [markdown]
# ### Predcition from the model

# %%
pred = lm.predict(X_test)

# %%
plt.scatter(y_test, pred)

# %%
sns.histplot((y_test-pred), kde=True, bins=50)
# Out:
# <AxesSubplot: xlabel='Cooling_Load', ylabel='Count'>

# %% [markdown]
# ### Regression Evaluation Metrics

# %%
from sklearn import metrics

# %%
print('MAE: ', metrics.mean_absolute_error(y_test, pred))
print('MSE: ', metrics.mean_squared_error(y_test, pred))
print('RMSE: ', np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# MAE:  2.0764189500414756
# MSE:  9.228247309908507
# RMSE:  3.0378030400123883
